# %%
import time

# %%
t0 = time.time()
vals = []
for i in range(1, 10001):
        if i % 2 == 1:
                i *= -1
        vals.append(1)
print('runtime:', time.time() - t0)
# Out:
# runtime: 0.0010883808135986328

# %%
t0 = time.time()
vals = [i * -1 if i %2 == 1 else i for i in range(1,100001)]
print('runtime:', time.time() - t0)
# Out:
# runtime: 0.006368398666381836

# %%
import numpy as np

# %%
randos = np.random.randint(1,7,10)

# %%
r1 = np.random.randint(11)

# %%
type(r1)
# Out:
# int

# %%
r2 = np.random.randint(1,21,5)

# %%
type(r2)
# Out:
# numpy.ndarray

# %%
from matplotlib.pyplot import hist

# %%
hist(r2)
# Out:
# (array([2., 0., 0., 0., 0., 0., 0., 1., 0., 2.]),
#  array([ 8. ,  9.2, 10.4, 11.6, 12.8, 14. , 15.2, 16.4, 17.6, 18.8, 20. ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.randn(2, 3)

# %%
x
# Out:
# array([[ 0.42941367, -0.68144847, -0.7567088 ],
#        [-0.58403062,  1.92650771,  1.93457011]])

# %%
x * 2
# Out:
# array([[ 0.85882735, -1.36289695, -1.5134176 ],
#        [-1.16806124,  3.85301543,  3.86914022]])

# %%
x + x
# Out:
# array([[ 0.85882735, -1.36289695, -1.5134176 ],
#        [-1.16806124,  3.85301543,  3.86914022]])

# %%
1/x
# Out:
# array([[ 2.32875677, -1.46746238, -1.32151232],
#        [-1.71223899,  0.51907397,  0.5169107 ]])

# %%
shape = (2,4)

# %%
z1 = np.zeros(shape)

# %%
z1
# Out:
# array([[0., 0., 0., 0.],
#        [0., 0., 0., 0.]])

# %%
o1 = np.ones(shape)

# %%
o1
# Out:
# array([[1., 1., 1., 1.],
#        [1., 1., 1., 1.]])

# %%
np.indentity(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 np.indentity(4)
#
# File /apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/site-packages/numpy/__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'indentity'

# %%
x12 = np.random.rand(5)

# %%
x12
# Out:
# array([0.70127944, 0.63594912, 0.3917182 , 0.34936366, 0.80215713])

# %%
x12[1:4]
# Out:
# array([0.63594912, 0.3917182 , 0.34936366])

# %%
x12[1:-1]
# Out:
# array([0.63594912, 0.3917182 , 0.34936366])

# %%
x12[x12 > 0.15]
# Out:
# array([0.70127944, 0.63594912, 0.3917182 , 0.34936366, 0.80215713])

# %%
x14 = np.random.randn(3,3)

# %%
x14
# Out:
# array([[ 1.053628  ,  1.37979406,  0.49061508],
#        [-0.57423195, -0.44717646,  0.32897809],
#        [-1.0703194 ,  1.41606546,  1.5670689 ]])

# %%
x14[1:, : -1]
# Out:
# array([[-0.57423195, -0.44717646],
#        [-1.0703194 ,  1.41606546]])

# %%
x14[1:, :2]
# Out:
# array([[-0.57423195, -0.44717646],
#        [-1.0703194 ,  1.41606546]])
